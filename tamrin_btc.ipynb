# %%
import yfinance as yf
import pandas as pd
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
btc = yf.download('BTC-USD', period='max',start='2019-01-01')
df = pd.DataFrame(btc)
df.drop(columns=['Volume','Adj Close','Low'], inplace=True)
df.reset_index(inplace=True) 
df['DayWeek'] = df['Date'].dt.dayofweek
df = df[df['DayWeek'].isin([5, 2])]
df.reset_index(inplace=True)
if df.loc[0,'DayWeek'] == 2:
     df.drop(index=0, inplace=True)
df['new_close'] = df['Close'].shift(-1)
df['new_high'] = df['High'].shift(-1)
df = df[df['DayWeek'].isin([5])]
df.drop(columns=['index','DayWeek'], inplace=True)
df['start_point'] = df['end_point'] = 1000.0
df.to_csv('BTC.csv',index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
df = pd.read_csv('BTC.csv')
ratio = df['new_close'] / df['Open']
df['end_point'] = df['start_point'] * ratio.cumprod()
df['start_point'] = df['end_point'].shift(1)
df['btc'] = df['start_point']/df['Open']
df.reset_index(drop=True, inplace=True)
df.to_csv("BTC(open-close).csv",index=False)
df
# Out:
#            Date          Open          High         Close     new_close  \
# 0    2019-01-05   3851.973877   3904.903076   3845.194580   4035.296387
# 1    2019-01-12   3686.973145   3698.978271   3661.301025   3655.006836
# 2    2019-01-19   3652.377930   3758.533447   3728.568359   3585.123047
# 3    2019-01-26   3599.715332   3654.933105   3602.460449   3486.181641
# 4    2019-02-02   3484.625977   3523.287354   3521.060791   3413.767822
# ..          ...           ...           ...           ...           ...
# 288  2024-07-13  57908.738281  59787.078125  59231.953125  64118.792969
# 289  2024-07-20  66709.921875  67610.734375  67163.648438  65372.132812
# 290  2024-07-27  67911.812500  69398.507812  67813.335938  64619.250000
# 291  2024-08-03  61414.808594  62148.371094  60680.093750  55027.460938
# 292  2024-08-10  60881.230469  61464.511719  60945.812500           NaN
#
#          new_high   start_point     end_point       btc               text
# 0     4068.403564           NaN   1047.591836       NaN      wallet : nan$
# 1     3685.777100   1047.591836   1038.509144  0.284133   wallet : 1048.0$
# 2     3623.067871   1038.509144   1019.386037  0.284338   wallet : 1039.0$
# 3     3495.174805   1019.386037    987.234978  0.283185   wallet : 1019.0$
# 4     3469.091797    987.234978    967.160041  0.283312    wallet : 987.0$
# ..            ...           ...           ...       ...                ...
# 288  66066.734375  20350.136375  22532.457447  0.351417  wallet : 20350.0$
# 289  67113.984375  22532.457447  22080.595501  0.337768  wallet : 22532.0$
# 290  66810.210938  22080.595501  21010.063909  0.325136  wallet : 22081.0$
# 291  57726.882812  21010.063909  18824.946255  0.342101  wallet : 21010.0$
# 292           NaN  18824.946255           NaN  0.309208  wallet : 18825.0$
#
# [293 rows x 10 columns]

# %%
df = pd.read_csv('BTC(open-close).csv')
fig = make_subplots(rows=1, cols=2)
df['text'] = 'wallet : ' + df['start_point'].round().astype(str) + '$'
fig.add_trace(go.Scatter(x=df['Date'], y=df['start_point'],text=df['text'],name='$'),row=1, col=1)
df['text'] = 'wallet : ' + df['btc'].round(2).astype(str) + 'BTC'
fig.add_trace(go.Scatter(x=df['Date'], y=df['btc'],text=df['text'],name='BTC'),row=1, col=2)

fig.update_layout(width=1300,height=500,)
fig.show()
# Out:
# <div>                            <div id="8b8f6844-3974-4731-afee-d3e1f7c04ce1" class="plotly-graph-div" style="height:500px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8
: 9415.0$","wallet : 8850.0$","wallet : 9155.0$","wallet : 9633.0$","wallet : 8797.0$","wallet : 8276.0$","wallet : 8752.0$","wallet : 8476.0$","wallet : 8565.0$","wallet : 8377.0$","wallet : 8950.0$","wallet : 9277.0$","wallet : 8644.0$","wallet : 9683.0$","wallet : 10384.0$","wallet : 11012.0$","wallet : 11302.0$","wallet : 11993.0$","wallet : 11195.0$","wallet : 10900.0$","wallet : 11121.0$","wallet : 10982.0$","wallet : 11293.0$","wallet : 9066.0$","wallet : 8891.0$","wallet : 9001.0$","wallet : 9371.0$","wallet : 9532.0$","wallet : 7398.0$"," ...

# %%
df = pd.read_csv('BTC.csv')
ratio = df['new_high'] / df['Open']
df['end_point'] = df['start_point'] * ratio.cumprod()
df['start_point'] = df['end_point'].shift(1)
df['btc'] = df['start_point']/df['Open']
df.reset_index(drop=True, inplace=True)
df.to_csv("BTC(open-high).csv",index=False)
df
# Out:
#            Date          Open          High         Close     new_close  \
# 0    2019-01-05   3851.973877   3904.903076   3845.194580   4035.296387
# 1    2019-01-12   3686.973145   3698.978271   3661.301025   3655.006836
# 2    2019-01-19   3652.377930   3758.533447   3728.568359   3585.123047
# 3    2019-01-26   3599.715332   3654.933105   3602.460449   3486.181641
# 4    2019-02-02   3484.625977   3523.287354   3521.060791   3413.767822
# ..          ...           ...           ...           ...           ...
# 288  2024-07-13  57908.738281  59787.078125  59231.953125  64118.792969
# 289  2024-07-20  66709.921875  67610.734375  67163.648438  65372.132812
# 290  2024-07-27  67911.812500  69398.507812  67813.335938  64619.250000
# 291  2024-08-03  61414.808594  62148.371094  60680.093750  55027.460938
# 292  2024-08-10  60881.230469  61464.511719  60945.812500           NaN
#
#          new_high   start_point     end_point         btc
# 0     4068.403564           NaN  1.056187e+03         NaN
# 1     3685.777100  1.056187e+03  1.055844e+03    0.286464
# 2     3623.067871  1.055844e+03  1.047371e+03    0.289084
# 3     3495.174805  1.047371e+03  1.016954e+03    0.290959
# 4     3469.091797  1.016954e+03  1.012420e+03    0.291840
# ..            ...           ...           ...         ...
# 288  66066.734375  9.112533e+06  1.039628e+07  157.360235
# 289  67113.984375  1.039628e+07  1.045925e+07  155.843037
# 290  66810.210938  1.045925e+07  1.028959e+07  154.012193
# 291  57726.882812  1.028959e+07  9.671703e+06  167.542443
# 292           NaN  9.671703e+06           NaN  158.861819
#
# [293 rows x 9 columns]

# %%
fig = make_subplots(rows=1, cols=2)

df['text'] = 'Balance : ' + df['start_point'].round(2).astype(str) + '$'
fig.add_trace(go.Scatter(x=df['Date'], y=df['start_point'],text=df['text'],name='$'),row=1, col=1)
df['text'] = 'wallet : ' + df['btc'].round(2).astype(str) + 'BTC'
fig.add_trace(go.Scatter(x=df['Date'], y=df['btc'],text=df['text'],name='BTC'),row=1, col=2)
fig.update_layout(width=1300,height=500)
fig.show()
# Out:
# <div>                            <div id="255aacfd-7a78-4f68-871d-ec81db67d1f3" class="plotly-graph-div" style="height:500px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById